# %% [markdown]
# # using rapid api

# %%
import pandas as pd

# %%
import requests

url = "https://maps-data.p.rapidapi.com/nearby.php"

querystring = {"query":"restaurant","lat":"17.4875","lng":"78.3953","limit":"20","country":"india","lang":"en","offset":"0","zoom":"12"}

headers = {
	"x-rapidapi-key": "dff16cce07msh02d70244604eee2p13ba0bjsne936990e1e46",
	"x-rapidapi-host": "maps-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pd.json_normalize(response.json(),record_path=['data'])
# Out:
#                               business_id phone_number  \
# 0    0x3bcb91a43d378b27:0xf27e6946d605483  06305521329
# 1   0x3bcb918dd49f74a9:0x29a66ae6120234b7  08186004000
# 2   0x3bcb915fd4969abb:0x8f73fa076dfbc9c0  09866663156
# 3   0x3bcb91007a426f89:0x60e5629fcbcbf802         None
# 4   0x3bcb910ea0927dfd:0x86fa89c025122988  09133091330
# 5   0x3bcb9b0d3feb8ec3:0xdb9d6c7d211f7b92  09188802888
# 6   0x3bcb9122171978bb:0xeb8bdb918294c473  09963944555
# 7   0x3bcb91586e24b117:0x5a5b6c762052635e         None
# 8   0x3bcb91692ec06023:0x3ff54623482780f7         None
# 9   0x3bcb91705b103921:0x256c7ee63d9b9e1a         None
# 10  0x3bcb912211287db3:0x5e86e46258cb1349         None
# 11  0x3bcb91830770627f:0xa00a63245b8c958a  09000787687
# 12  0x3bcb91f9ab964c1f:0x22103b45872f7d3e  09182682221
# 13  0x3bcb918c2a1bffff:0x8aa2ac52237ac764  09704992939
# 14  0x3bcb910019f039f1:0x5aa99d28bdc8e70f         None
# 15  0x3bcb918dab39052f:0x9ca125055351a66e  09540016985
# ...

# %% [markdown]
# # WebScraping

# %% [markdown]
# # Repositories

# %% [markdown]
# ### website names: kaggel, uci, dataworld
