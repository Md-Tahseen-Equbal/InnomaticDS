# %%
import pandas as pd

# %%
encoding = [
    "ASCII",
    "UTF-8",
    "UTF-16",
    "UTF-32",
    "ISO-8859-1",
    "Windows-1252",
    "UTF-7",
    "UTF-EBCDIC",
    "UTF-16LE",
    "UTF-16BE",
    "UTF-32LE",
    "UTF-32BE",
    "ISO-8859-2",
    "ISO-8859-3",
    "ISO-8859-4",
    "ISO-8859-5",
    "ISO-8859-6",
    "ISO-8859-7",
    "ISO-8859-8",
    "ISO-8859-9",
    "ISO-8859-10",
    "ISO-8859-11",
    "ISO-8859-13",
    "ISO-8859-14",
    "ISO-8859-15",
    "ISO-8859-16",
    "KOI8-R",
    "KOI8-U",
    "GB2312",
    "GBK",
    "Shift_JIS",
    "EUC-JP"
]

# %%
for i in encoding:
    try:
        pd.read_csv("..\Data Extraction\Datasets\Diwali Sales Data.csv",encoding = i)
        print(i)
    except (UnicodeDecodeError,LookupError,UnicodeError):
        pass
# Out:
# ISO-8859-1
# Windows-1252
# ISO-8859-2
# ISO-8859-3
# ISO-8859-4
# ISO-8859-5
# ISO-8859-7
# ISO-8859-9
# ISO-8859-10
# ISO-8859-13
# ISO-8859-14
# ISO-8859-15
# ISO-8859-16
# KOI8-R
# KOI8-U
# GBK

# %%
pd.read_csv(r"..\Data Extraction\Datasets\Diwali Sales Data.csv",encoding ="ISO-8859-3")
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
pd.read_csv(r"..\Data Extraction\Datasets\reduced_household_power_consumption.txt",sep=';')
# Out:
# C:\Users\91830\AppData\Local\Temp\ipykernel_624\3310227346.py:1: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r"..\Data Extraction\Datasets\reduced_household_power_consumption.txt",sep=';')
#              Date      Time Global_active_power Global_reactive_power  \
# 0      16/12/2006  17:24:00               4.216                 0.418
# 1      16/12/2006  17:25:00               5.360                 0.436
# 2      16/12/2006  17:26:00               5.374                 0.498
# 3      16/12/2006  17:27:00               5.388                 0.502
# 4      16/12/2006  17:28:00               3.666                 0.528
# ...           ...       ...                 ...                   ...
# 74994    6/2/2007  19:18:00               0.308                   0.0
# 74995    6/2/2007  19:19:00               0.308                   0.0
# 74996    6/2/2007  19:20:00               0.308                   0.0
# ...

# %%
pd.read_excel(r"..\Data Extraction\Datasets\Sample - Superstore.xls",sheet_name= 1)
# Out:
#     Returned        Order ID
# 0        Yes  CA-2017-153822
# 1        Yes  CA-2017-129707
# 2        Yes  CA-2014-152345
# 3        Yes  CA-2015-156440
# 4        Yes  US-2017-155999
# ..       ...             ...
# 291      Yes  CA-2015-101910
# 292      Yes  CA-2017-156958
# 293      Yes  CA-2016-105585
# 294      Yes  CA-2016-148796
# 295      Yes  CA-2015-149636
#
# [296 rows x 2 columns]
