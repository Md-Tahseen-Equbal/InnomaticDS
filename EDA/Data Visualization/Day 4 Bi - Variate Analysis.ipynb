# %% [markdown]
# # Bi Variate Analysis

# %% [markdown]
# ## Analysis of two column of at a time
# 1. Numerical & Numerical   - Scatter plot
# 2. Numerical & Categorical - Bar and Box plot
# 3. Categorical & Categorical - Cross Tab

# %% [markdown]
# ### Scatter Plot
# 1. Purpose - Finding relationship between two column
#  - x axis- independent value
#  - y axis- dependent value

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.scatterplot(data = df,x = "acceleration",y="mpg")
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
sns.scatterplot(data = df,x = "weight",y="mpg")
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
data = pd.DataFrame({"x": [1,2,3,4],
             "y": [6,7,2,9]})

# %%
data.corr()
# Out:
#           x         y
# x  1.000000  0.175412
# y  0.175412  1.000000

# %%
sns.scatterplot(data = data,x = 'x',y = 'y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df1 = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.scatterplot(data = df, x ='displacement', y = 'mpg', hue = 'cylinders', palette='bright')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='mpg'>

# %%
sns.scatterplot(data = df, x ='acceleration', y = 'mpg', hue = 'cylinders', palette='bright')
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data = df, x ='sepal_length', y ='petal_width', hue = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df.corr(numeric_only=True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.scatterplot(data = df, x ='sepal_width', y ='petal_length', hue = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>

# %% [markdown]
# - **setosa** -> ranges from 2.3 to 4.4 sepal width and 1 to 2 as petal length
# - **versicolor** -> ranges from 2.0 to 3.4 sepal width and 3 to 5 as petal length
# - **virginica** -> ranges from 2.2 to 3.9 sepal width and 4.5 to 7 as petal length
# - **Negative Moderate - -0.42**

# %% [markdown]
# ## scatter plot
#  - To find the relationship
#  - Direction - Increasing/ Decreasing
#  - Strength - How closed the data points are.
#  - DISADV
#  - we can find the relationship b/w two column at a time.
#  - strength is subjective we cant quantify the strength

# %% [markdown]
# ####  HeatMap used for (Multi - Variate)

# %%
sns.heatmap(df1.corr(numeric_only=True),annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(numeric_only=True),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Numerical & Categorical
# - LinePlot (Trend)
# - Bar Plot (Comparision)

# %% [markdown]
# ## Line Plot
# - x-axis must be day/date/time.

# %%
df = sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(data = df,x = 'year',y = 'passengers', estimator='sum', hue = 'month', palette="dark")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data = df,x = 'month',y = 'passengers', estimator='mean', hue = 'year', palette="dark")
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
df2 = sns.load_dataset('fmri')

# %%
df2.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
sns.lineplot(data = df2, x = 'timepoint', y = 'signal')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
df3 = sns.load_dataset('tips')

# %%
df3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(data = df3, x = 'day', y = 'total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# sns.barplot(data = df3, x = 'day', y = 'total_bill', hue = 'smoker')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## StackBar Plot

# %%
plt.bar(df3['sex'],df3['total_bill'])
plt.bar(df3['sex'],df3['tip'])
plt.bar(df3['sex'],df3['size'])
plt.legend(['total_bill','tip','size'])

# %%
df3['tip'].mean()
# Out:
# 2.99827868852459
