# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Time series Data\time_series.csv")
df
# Out:
#           ID          Datetime  Count
# 0          0  25-08-2012 00:00      8
# 1          1  25-08-2012 01:00      2
# 2          2  25-08-2012 02:00      6
# 3          3  25-08-2012 03:00      2
# 4          4  25-08-2012 04:00      2
# ...      ...               ...    ...
# 18283  18283  25-09-2014 19:00    868
# 18284  18284  25-09-2014 20:00    732
# 18285  18285  25-09-2014 21:00    702
# 18286  18286  25-09-2014 22:00    580
# 18287  18287  25-09-2014 23:00    534
#
# [18288 rows x 3 columns]

# %% [markdown]
# # Time Series

# %%
df.shape
# Out:
# (18288, 3)

# %%
df.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %%
df['Datetime']=pd.to_datetime(df['Datetime'])

# %%
df['Datetime'].dt.day   # dt-- Day time ---Day
# Out:
# 0        25
# 1        25
# 2        25
# 3        25
# 4        25
#          ..
# 18283    25
# 18284    25
# 18285    25
# 18286    25
# 18287    25
# Name: Datetime, Length: 18288, dtype: int64

# %%
df['Datetime'].dt.month  # --- Month
# Out:
# 0        8
# 1        8
# 2        8
# 3        8
# 4        8
#         ..
# 18283    9
# 18284    9
# 18285    9
# 18286    9
# 18287    9
# Name: Datetime, Length: 18288, dtype: int64

# %%
df['Datetime'].dt.year # --- Year
# Out:
# 0        2012
# 1        2012
# 2        2012
# 3        2012
# 4        2012
#          ...
# 18283    2014
# 18284    2014
# 18285    2014
# 18286    2014
# 18287    2014
# Name: Datetime, Length: 18288, dtype: int64

# %%
df.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %%
df['Month']=df['Datetime'].dt.month

# %%
df.head()
# Out:
#    ID            Datetime  Count  Month
# 0   0 2012-08-25 00:00:00      8      8
# 1   1 2012-08-25 01:00:00      2      8
# 2   2 2012-08-25 02:00:00      6      8
# 3   3 2012-08-25 03:00:00      2      8
# 4   4 2012-08-25 04:00:00      2      8

# %%
df['Day']=df['Datetime'].dt.day

# %%
df.head()
# Out:
#    ID            Datetime  Count  Month  Day
# 0   0 2012-08-25 00:00:00      8      8   25
# 1   1 2012-08-25 01:00:00      2      8   25
# 2   2 2012-08-25 02:00:00      6      8   25
# 3   3 2012-08-25 03:00:00      2      8   25
# 4   4 2012-08-25 04:00:00      2      8   25

# %%
df['Year']=df['Datetime'].dt.year

# %%
df.head()
# Out:
#    ID            Datetime  Count  Month  Day  Year
# 0   0 2012-08-25 00:00:00      8      8   25  2012
# 1   1 2012-08-25 01:00:00      2      8   25  2012
# 2   2 2012-08-25 02:00:00      6      8   25  2012
# 3   3 2012-08-25 03:00:00      2      8   25  2012
# 4   4 2012-08-25 04:00:00      2      8   25  2012

# %%
# I want Month name 

df['Datetime'].dt.month_name()
# Out:
# 0           August
# 1           August
# 2           August
# 3           August
# 4           August
#            ...
# 18283    September
# 18284    September
# 18285    September
# 18286    September
# 18287    September
# Name: Datetime, Length: 18288, dtype: object

# %%
# I want Day name 

df['Datetime'].dt.day_name()
# Out:
# 0        Saturday
# 1        Saturday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 18283    Thursday
# 18284    Thursday
# 18285    Thursday
# 18286    Thursday
# 18287    Thursday
# Name: Datetime, Length: 18288, dtype: object

# %%
# I want Year name 

df['Datetime'].dt.year_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2676\1274844580.py in <module>
#       1 # I want Year name
#       2
# ----> 3 df['Datetime'].dt.year_name()
#
# AttributeError: 'DatetimeProperties' object has no attribute 'year_name'

# %%
# Now performing on time Stamp Data set  to transform the data

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Time series Data\data_with_timestamp.csv")
df
# Out:
#           ID   timestamp  Count
# 0          0  1345852800      8
# 1          1  1345856400      2
# 2          2  1345860000      6
# 3          3  1345863600      2
# 4          4  1345867200      2
# ...      ...         ...    ...
# 18283  18283  1411671600    868
# 18284  18284  1411675200    732
# 18285  18285  1411678800    702
# 18286  18286  1411682400    580
# 18287  18287  1411686000    534
#
# [18288 rows x 3 columns]

# %%
df.head()
# Out:
#    ID   timestamp  Count
# 0   0  1345852800      8
# 1   1  1345856400      2
# 2   2  1345860000      6
# 3   3  1345863600      2
# 4   4  1345867200      2

# %%
df.shape
# Out:
# (18288, 3)

# %%
df['DateTime']=pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#    ID   timestamp  Count                      Datetime  \
# 0   0  1345852800      8 1970-01-01 00:00:01.345852800
# 1   1  1345856400      2 1970-01-01 00:00:01.345856400
# 2   2  1345860000      6 1970-01-01 00:00:01.345860000
# 3   3  1345863600      2 1970-01-01 00:00:01.345863600
# 4   4  1345867200      2 1970-01-01 00:00:01.345867200
#
#                        DateTime
# 0 1970-01-01 00:00:01.345852800
# 1 1970-01-01 00:00:01.345856400
# 2 1970-01-01 00:00:01.345860000
# 3 1970-01-01 00:00:01.345863600
# 4 1970-01-01 00:00:01.345867200

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#    ID                     timestamp  Count                      Datetime  \
# 0   0 1970-01-01 00:00:01.345852800      8 1970-01-01 00:00:01.345852800
# 1   1 1970-01-01 00:00:01.345856400      2 1970-01-01 00:00:01.345856400
# 2   2 1970-01-01 00:00:01.345860000      6 1970-01-01 00:00:01.345860000
# 3   3 1970-01-01 00:00:01.345863600      2 1970-01-01 00:00:01.345863600
# 4   4 1970-01-01 00:00:01.345867200      2 1970-01-01 00:00:01.345867200
#
#                        DateTime
# 0 1970-01-01 00:00:01.345852800
# 1 1970-01-01 00:00:01.345856400
# 2 1970-01-01 00:00:01.345860000
# 3 1970-01-01 00:00:01.345863600
# 4 1970-01-01 00:00:01.345867200

# %% [markdown]
# # Cross Tab
#
# ### --->Categorical and Categorical
#
# ### ---> Frequency, Count , Percentiles

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\loandata.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
pd.crosstab(df['Gender'],df['Married'])    # Categorical --- categorical Data set Relation
# Out:
# Married   No  Yes
# Gender
# Female    80   31
# Male     130  357

# %%
pd.crosstab(index=df['Gender'],columns=df['Married'])
# Out:
# Married   No  Yes
# Gender
# Female    80   31
# Male     130  357

# %%
pd.crosstab(columns=df['Gender'],index=df['Married'])
# Out:
# Gender   Female  Male
# Married
# No           80   130
# Yes          31   357

# %%
pd.crosstab(columns=df['Gender'],index=df['Married'],normalize=True)*100   # It represent data in percentile
# Out:
# Gender      Female       Male
# Married
# No       13.377926  21.739130
# Yes       5.183946  59.698997

# %%
# Cross Tab Relation for --- Education and Loan_Status

# %%
pd.crosstab(columns=df['Education'],index=df['Loan_Status'])
# Out:
# Education    Graduate  Not Graduate
# Loan_Status
# N                 140            52
# Y                 340            82

# %%
pd.crosstab(columns=df['Education'],
           index=df['Loan_Status'],
           values=df['ApplicantIncome'],
           aggfunc='max')
# Out:
# Education    Graduate  Not Graduate
# Loan_Status
# N               81000          7660
# Y               63337         18165

# %%
pd.crosstab(columns=df['Education'],
           index=df['Loan_Status'],
           values=df['ApplicantIncome'],
           aggfunc='max',)
# Out:
# Education    Graduate  Not Graduate
# Loan_Status
# N               81000          7660
# Y               63337         18165

# %%
# Gender self employed and loan_amount  --- Create Cross Tab

# %%
pd.crosstab(values=df['LoanAmount'],
            index=df['Self_Employed'],
           columns=df['Gender'],
           aggfunc='mean')
# Out:
# Gender             Female        Male
# Self_Employed
# No             117.747126  145.518135
# Yes            170.500000  170.475410

# %%
pd.crosstab(columns =[df['Education'],df['Gender']],
           index = df['Loan_Status'])
# Out:
# Education   Graduate      Not Graduate
# Gender        Female Male       Female Male
# Loan_Status
# N                 31  105            6   45
# Y                 61  271           14   68

# %% [markdown]
# # Pivot Table
#
# ## Reshaping
#
# ## ----> Categorical -- Numerical Data

# %%
pd.pivot_table(data = df,
               index =df['Education'],
               columns = df['Loan_Status'],
              values = 'ApplicantIncome',
              aggfunc = 'mean')
# Out:
# Loan_Status             N            Y
# Education
# Graduate      6114.514286  5751.576471
# Not Graduate  3646.442308  3860.256098

# %%
# Difference Pivot Table and Cross Tab

# %%
pd.pivot_table(data = df,
               columns =df['Education'],
               index = df['Loan_Status'])
# Out:
# C:\Users\91771\AppData\Local\Temp\ipykernel_2676\4136608075.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data = df,
#             ApplicantIncome              CoapplicantIncome               \
# Education          Graduate Not Graduate          Graduate Not Graduate
# Loan_Status
# N               6114.514286  3646.442308       2111.028571  1249.903846
# Y               5751.576471  3860.256098       1555.423294  1293.439024
#
#             Credit_History               LoanAmount               \
# Education         Graduate Not Graduate    Graduate Not Graduate
# Loan_Status
# N                 0.561538     0.489796  161.388060   122.234043
# Y                 0.980831     0.986111  151.093656   116.162500
#
#             Loan_Amount_Term
# ...

# %%
pd.crosstab(columns=df['Education'],
           index=df['Loan_Status'])
# Out:
# Education    Graduate  Not Graduate
# Loan_Status
# N                 140            52
# Y                 340            82

# %% [markdown]
# # Group by
# ### --> Splitting
#
# ### --> Apply
#
# ### ---> Transform
#
# ### ---> For All type of Data

# %%
df.groupby(by="Education")['ApplicantIncome'].agg(np.max)
# Out:
# Education
# Graduate        81000
# Not Graduate    18165
# Name: ApplicantIncome, dtype: int64

# %%
df.groupby(by="Education")['ApplicantIncome'].agg([np.max,np.min,np.mean])
# Out:
#                amax  amin         mean
# Education
# Graduate      81000   150  5857.433333
# Not Graduate  18165   210  3777.283582

# %%
df.groupby(by=["Education",'Loan_Status'])['ApplicantIncome'].agg([np.max,np.min,np.mean])
# Out:
#                            amax  amin         mean
# Education    Loan_Status
# Graduate     N            81000   150  6114.514286
#              Y            63337   645  5751.576471
# Not Graduate N             7660  1442  3646.442308
#              Y            18165   210  3860.256098

# %%
df.groupby(by=["Education",'Loan_Status'])
[['ApplicantIncome','LoanAmount']].agg([np.max,np.min,np.mean])
# Out:
#                          ApplicantIncome                    LoanAmount        \
#                                     amax  amin         mean       amax  amin
# Education    Loan_Status
# Graduate     N                     81000   150  6114.514286      570.0   9.0
#              Y                     63337   645  5751.576471      700.0  17.0
# Not Graduate N                      7660  1442  3646.442308      218.0  35.0
#              Y                     18165   210  3860.256098      279.0  25.0
#
#
#                                 mean
# Education    Loan_Status
# Graduate     N            161.388060
#              Y            151.093656
# Not Graduate N            122.234043
#              Y            116.162500
