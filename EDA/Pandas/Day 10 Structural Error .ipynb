# %%
import numpy as np
import pandas as pd

# %%
# Structural Error

# %%
df=pd.DataFrame({'Brand':['Apple','MI','Apple','Samsung','MI','OPPO'],
             'RAM':['-',4,'?',8,4,8],
              'Price':['80,600','40,500','95,000','80,000','20,000','15,000']
             
             })
df
# Out:
#      Brand RAM   Price
# 0    Apple   -  80,600
# 1       MI   4  40,500
# 2    Apple   ?  95,000
# 3  Samsung   8  80,000
# 4       MI   4  20,000
# 5     OPPO   8  15,000

# %%
df["Price"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\tf\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1629         try:
# -> 1630             x = float(x)
#    1631         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '80,60040,50095,00080,00020,00015,000'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\tf\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1633             try:
# -> 1634                 x = complex(x)
#    1635             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df["Price"]=df["Price"].str.replace(",","").astype('int')

# %%
df["Price"].mean()
# Out:
# 55183.333333333336

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\corrupted_data.csv")
df
# Out:
#    Unnamed: 0    Brand RAM   Price
# 0           0    Apple   -  80,600
# 1           1       MI   4  40,500
# 2           2    Apple   ?  95,000
# 3           3  Samsung   8  80,000
# 4           4       MI   4  20,000
# 5           5     OPPO   8  15,000

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\corrupted_data.csv",na_values=["-","?"])
df
# Out:
#    Unnamed: 0    Brand  RAM   Price
# 0           0    Apple  NaN  80,600
# 1           1       MI  4.0  40,500
# 2           2    Apple  NaN  95,000
# 3           3  Samsung  8.0  80,000
# 4           4       MI  4.0  20,000
# 5           5     OPPO  8.0  15,000

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\car_df_EDA.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0               0           1  alfa-romero       gas        std          two
# 1               1           2  alfa-romero       gas        std          two
# 2               2           3  alfa-romero       gas        std          two
# 3               3           4         audi       gas        std         four
# 4               4           5         audi       gas        std         four
# ..            ...         ...          ...       ...        ...          ...
# 203           203         204        volvo    diesel      turbo         four
# 204           204         205        volvo       gas      turbo         four
# 205           202         203        volvo       gas        std         four
# 206           203         204        volvo    diesel      turbo         four
# 207           204         205        volvo       gas      turbo         four
#
# ...

# %%
df.drop(['Unnamed: 0.1',"Unnamed: 0"],inplace = True,axis=1)

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           2
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          2
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                4
# dtype: int64

# %%
df.shape
# Out:
# (208, 22)

# %%
df["num_of_doors"].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
df["highway_mpg"].unique()
# Out:
# array([27, 26, 30, 22, 25, 20, 29, 28, 53, 43, 41, 38, 24, 54, 42, 34, 33,
#        31, 19, 17, 23, 32, 39, 18, 16, 37, 50, 36, 47, 46], dtype=int64)

# %%
df["price"].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', nan, '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\car_df_EDA.csv",na_values=["-","?"])
df
# Out:
#      Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0               0           1  alfa-romero       gas        std          two
# 1               1           2  alfa-romero       gas        std          two
# 2               2           3  alfa-romero       gas        std          two
# 3               3           4         audi       gas        std         four
# 4               4           5         audi       gas        std         four
# ..            ...         ...          ...       ...        ...          ...
# 203           203         204        volvo    diesel      turbo         four
# 204           204         205        volvo       gas      turbo         four
# 205           202         203        volvo       gas        std         four
# 206           203         204        volvo    diesel      turbo         four
# 207           204         205        volvo       gas      turbo         four
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0             0           1  alfa-romero       gas        std          two
# 1             1           2  alfa-romero       gas        std          two
# 2             2           3  alfa-romero       gas        std          two
# 3             3           4         audi       gas        std         four
# 4             4           5         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_type  \
# 0  convertible          rwd           front        88.6  ...         dohc
# 1  convertible          rwd           front        88.6  ...         dohc
# 2    hatchback          rwd           front        94.5  ...         ohcv
# 3        sedan          fwd           front        99.8  ...          ohc
# 4        sedan          4wd           front        99.4  ...          ohc
#
# ...

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\car_df_EDA.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0               0           1  alfa-romero       gas        std          two
# 1               1           2  alfa-romero       gas        std          two
# 2               2           3  alfa-romero       gas        std          two
# 3               3           4         audi       gas        std         four
# 4               4           5         audi       gas        std         four
# ..            ...         ...          ...       ...        ...          ...
# 203           203         204        volvo    diesel      turbo         four
# 204           204         205        volvo       gas      turbo         four
# 205           202         203        volvo       gas        std         four
# 206           203         204        volvo    diesel      turbo         four
# 207           204         205        volvo       gas      turbo         four
#
# ...

# %%
df.drop(['Unnamed: 0.1',"Unnamed: 0"],inplace = True,axis=1)

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)
