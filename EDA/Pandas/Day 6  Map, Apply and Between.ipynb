# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Sorting values

# %%
df = pd.DataFrame({"Names" : ['Mahesh','Suresh','Naresh','Prakash','Arjun'],
              "Marks": [66,34,45,66,55],
             "Grade": ['A','C','B','A','B'],
             "Age": [23,19,22,21,20]})

# %%
df
# Out:
#      Names  Marks Grade  Age
# 0   Mahesh     66     A   23
# 1   Suresh     34     C   19
# 2   Naresh     45     B   22
# 3  Prakash     66     A   21
# 4    Arjun     55     B   20

# %%
df.sort_values(by ='Marks', ascending = False, ignore_index = True, inplace = True)

# %%
df
# Out:
#      Names  Marks Grade  Age
# 0   Mahesh     66     A   23
# 1  Prakash     66     A   21
# 2    Arjun     55     B   20
# 3   Naresh     45     B   22
# 4   Suresh     34     C   19

# %%
df.sort_values(by= 'Age', ignore_index = True)
# Out:
#      Names  Marks Grade  Age
# 0   Suresh     34     C   19
# 1    Arjun     55     B   20
# 2  Prakash     66     A   21
# 3   Naresh     45     B   22
# 4   Mahesh     66     A   23

# %%
df.sort_values(by = ['Marks','Age'],ascending = [True,True], ignore_index = True)
# Out:
#      Names  Marks Grade  Age
# 0   Suresh     34     C   19
# 1   Naresh     45     B   22
# 2    Arjun     55     B   20
# 3  Prakash     66     A   21
# 4   Mahesh     66     A   23

# %% [markdown]
# ## Map, Apply and Between

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\loandata.csv")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %% [markdown]
# ### Apply
# - To transform the data. (from categorical <-> numerical)
# - Expect **Function**

# %% [markdown]
# #### Biserial Correlation
# - Finds the relationship between categorical and numerical

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\91771\anaconda3\envs\tf\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\91771\anaconda3\envs\tf\lib\site-packages (from scipy) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import pointbiserialr

# %%
def gender(x):
    if x == "Male":
        return 1
    else:
        return 0

# %%
df['Gender'] = df['Gender'].apply(gender) # when we have no inplace variable, just assign to the same thing .

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722       1     Yes          0      Graduate            No
# 1  LP002502       0     Yes          2  Not Graduate           NaN
# 2  LP002949       0      No         3+      Graduate           NaN
# 3  LP002603       0      No          0      Graduate            No
# 4  LP001644       0     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %%
corr,p_value = pointbiserialr(df['Gender'],df['ApplicantIncome'])

# %%
corr
# Out:
# 0.013933403563473733

# %%
p_value
# Out:
# 0.7304181759265278

# %%
def Property_Area(x):
    if x == "Rural":
        return 1
    elif x == "Semiurban":
        return 2
    else:
        return 3

# %%
df['Property_Area'] = df['Property_Area'].apply(Property_Area)

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722       1     Yes          0      Graduate            No
# 1  LP002502       0     Yes          2  Not Graduate           NaN
# 2  LP002949       0      No         3+      Graduate           NaN
# 3  LP002603       0      No          0      Graduate            No
# 4  LP001644       0     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              1           N
# 1             1.0              2           Y
# 2             NaN              3           N
# 3             1.0              1           Y
# 4             1.0              1           Y

# %%
def status(x):
    if x < 1000:
        return "POOR"
    elif x <6000:
        return "MIDDLE CLASS"
    else:
        return "RICH"

# %%
df['ApplicantIncome'] = df['ApplicantIncome'].apply(status)

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722       1     Yes          0      Graduate            No
# 1  LP002502       0     Yes          2  Not Graduate           NaN
# 2  LP002949       0      No         3+      Graduate           NaN
# 3  LP002603       0      No          0      Graduate            No
# 4  LP001644       0     Yes          0      Graduate           Yes
#
#   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            POOR             1800.0       135.0             360.0
# 1            POOR             2917.0        98.0             360.0
# 2            POOR            41667.0       350.0             180.0
# 3            POOR             3683.0       113.0             480.0
# 4            POOR             5296.0       168.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              1           N
# 1             1.0              2           Y
# 2             NaN              3           N
# 3             1.0              1           Y
# 4             1.0              1           Y

# %% [markdown]
# ### Map
# - To transform the data. (from categorical <-> numerical)
# - In single line
# - Expect **Dictionary**

# %%
df['Loan_Status'] = df['Loan_Status'].map({"N":0,"Y":1})

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722       1     Yes          0      Graduate            No
# 1  LP002502       0     Yes          2  Not Graduate           NaN
# 2  LP002949       0      No         3+      Graduate           NaN
# 3  LP002603       0      No          0      Graduate            No
# 4  LP001644       0     Yes          0      Graduate           Yes
#
#   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            POOR             1800.0       135.0             360.0
# 1            POOR             2917.0        98.0             360.0
# 2            POOR            41667.0       350.0             180.0
# 3            POOR             3683.0       113.0             480.0
# 4            POOR             5296.0       168.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              1            0
# 1             1.0              2            1
# 2             NaN              3            0
# 3             1.0              1            1
# 4             1.0              1            1

# %%
df['Education'] = df['Education'].map({"Graduate":1,"Not Graduate":0})

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents  Education Self_Employed  \
# 0  LP001722       1     Yes          0          1            No
# 1  LP002502       0     Yes          2          0           NaN
# 2  LP002949       0      No         3+          1           NaN
# 3  LP002603       0      No          0          1            No
# 4  LP001644       0     Yes          0          1           Yes
#
#   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            POOR             1800.0       135.0             360.0
# 1            POOR             2917.0        98.0             360.0
# 2            POOR            41667.0       350.0             180.0
# 3            POOR             3683.0       113.0             480.0
# 4            POOR             5296.0       168.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              1            0
# 1             1.0              2            1
# 2             NaN              3            0
# 3             1.0              1            1
# 4             1.0              1            1

# %% [markdown]
# ### Between
# - While encountering the between type of conditions, we can simply use .between()

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\loandata.csv")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %%
sum((df["CoapplicantIncome"]>=2000) & (df["CoapplicantIncome"]<=4000))
# Out:
# 144

# %%
sum(df["CoapplicantIncome"].between(2000,4000))
# Out:
# 144

# %% [markdown]
# ## Time Series (Date/Time)

# %%
date = pd.date_range(start = '5/8/2024', end ="5/15/2024") # MM/DD/YYYY

# %%
sales = np.random.randint(10,50,8)

# %%
df = pd.DataFrame({"date":date,
             "sales":sales})

# %%
df
# Out:
#         date  sales
# 0 2024-05-08     48
# 1 2024-05-09     12
# 2 2024-05-10     25
# 3 2024-05-11     14
# 4 2024-05-12     36
# 5 2024-05-13     29
# 6 2024-05-14     48
# 7 2024-05-15     33
