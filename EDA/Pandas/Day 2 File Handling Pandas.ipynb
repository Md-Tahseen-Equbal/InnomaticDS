# %% [markdown]
# # Pandas File Handling
#
# ## File - Data Storage
#
# ### --> Files are two types - Structured , Semi Structured , Unstructured Data

# %% [markdown]
# # Structured Data

# %%
# Data Represent in row ,column 
# Excel,csv
# Tabular Format

# %% [markdown]
# # Semi structured

# %%
#Json ,html ,xml

# %% [markdown]
# # Unstructured Data

# %%
# Image ,videos, audio, text

# %% [markdown]
# # Important in Pandas
#
# Firstly know that
#
#  Extension
#
#  Encoding

# %% [markdown]
# # File Loading Path

# %% [markdown]
# ## - Fle Path --

# %% [markdown]
# # File Handling

# %%
import pandas as pd

# %% [markdown]
# ## CSV File

# %%
pd.read_csv(r'C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\adult_csv.csv')
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0        2         State-gov   77516  Bachelors             13
# 1        3  Self-emp-not-inc   83311  Bachelors             13
# 2        2           Private  215646    HS-grad              9
# 3        3           Private  234721       11th              7
# 4        1           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837    2           Private  215419  Bachelors             13
# 48838    4               NaN  321403    HS-grad              9
# 48839    2           Private  374983  Bachelors             13
# 48840    2           Private   83891  Bachelors             13
# 48841    1      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\91771\\EDA\\Pandas'

# %%
pd.read_csv('loandata.csv')  ## If data in Current working Directory
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # TXT file

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\reduced_household_power_consumption.txt") # It is an messy because we load on CSV fle to an TXT file
# Out:
#       Date;Time;Global_active_power;Global_reactive_power;Voltage;Global_intensity;Sub_metering_1;Sub_metering_2;Sub_metering_3
# 0      16/12/2006;17:24:00;4.216;0.418;234.840;18.400...
# 1      16/12/2006;17:25:00;5.360;0.436;233.630;23.000...
# 2      16/12/2006;17:26:00;5.374;0.498;233.290;23.000...
# 3      16/12/2006;17:27:00;5.388;0.502;233.740;23.000...
# 4      16/12/2006;17:28:00;3.666;0.528;235.680;15.800...
# ...                                                  ...
# 74994  6/2/2007;19:18:00;0.308;0.0;239.94;1.2;0.0;0.0...
# 74995  6/2/2007;19:19:00;0.308;0.0;240.15;1.2;0.0;0.0...
# 74996  6/2/2007;19:20:00;0.308;0.0;239.93;1.2;0.0;0.0...
# 74997  6/2/2007;19:21:00;0.302;0.0;237.95;1.2;0.0;0.0...
# 74998  6/2/2007;19:22:00;0.306;0.0;239.29;1.2;0.0;0.0...
#
# [74999 rows x 1 columns]

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\reduced_household_power_consumption.txt",sep = ';')
# Out:
# C:\Users\91771\AppData\Local\Temp\ipykernel_9272\3752419126.py:1: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\reduced_household_power_consumption.txt",sep = ';')
#              Date      Time Global_active_power Global_reactive_power  \
# 0      16/12/2006  17:24:00               4.216                 0.418
# 1      16/12/2006  17:25:00               5.360                 0.436
# 2      16/12/2006  17:26:00               5.374                 0.498
# 3      16/12/2006  17:27:00               5.388                 0.502
# 4      16/12/2006  17:28:00               3.666                 0.528
# ...           ...       ...                 ...                   ...
# 74994    6/2/2007  19:18:00               0.308                   0.0
# 74995    6/2/2007  19:19:00               0.308                   0.0
# ...

# %% [markdown]
# # Header Changes

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1.0            5.1           3.5            1.4           0.2
# 1    2.0            4.9           3.0            1.4           0.2
# 2    3.0            NaN           3.2            1.3           0.2
# 3    4.0            4.6           3.1            1.5           0.2
# 4    5.0            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 161  NaN            6.7           3.1            5.6           2.4
# 162  NaN            6.9           3.1            5.1           2.3
# 163  NaN            5.8           2.7            5.1           1.9
# 164  NaN            6.8           3.2            NaN           2.3
# 165  NaN            6.7           3.3            5.7           2.5
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",header = 1)
# Out:
#        1  5.1  3.5  1.4  0.2     Iris-setosa
# 0    2.0  4.9  3.0  1.4  0.2     Iris-setosa
# 1    3.0  NaN  3.2  1.3  0.2     Iris-setosa
# 2    4.0  4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  5.0  3.6  1.4  0.2     Iris-setosa
# 4    6.0  5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 160  NaN  6.7  3.1  5.6  2.4  Iris-virginica
# 161  NaN  6.9  3.1  5.1  2.3  Iris-virginica
# 162  NaN  5.8  2.7  5.1  1.9  Iris-virginica
# 163  NaN  6.8  3.2  NaN  2.3  Iris-virginica
# 164  NaN  6.7  3.3  5.7  2.5  Iris-virginica
#
# [165 rows x 6 columns]

# %% [markdown]
# # Rename column Header

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",names =['A','B','C','D','E','F'])
# Out:
#        A              B             C              D             E  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9             3            1.4           0.2
# 3      3            NaN           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 162  NaN            6.7           3.1            5.6           2.4
# 163  NaN            6.9           3.1            5.1           2.3
# 164  NaN            5.8           2.7            5.1           1.9
# 165  NaN            6.8           3.2            NaN           2.3
# 166  NaN            6.7           3.3            5.7           2.5
#
#                   F
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",usecols=['SepalLengthCm','SepalWidthCm'])
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              NaN           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 161            6.7           3.1
# 162            6.9           3.1
# 163            5.8           2.7
# 164            6.8           3.2
# 165            6.7           3.3
#
# [166 rows x 2 columns]

# %% [markdown]
# # Want Rows

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",nrows = 100)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            NaN           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96           57.0           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2          12.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           NaN            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",usecols=['PetalLengthCm','PetalWidthCm'],nrows=10)
# Out:
#    PetalLengthCm  PetalWidthCm
# 0            1.4           0.2
# 1            1.4           0.2
# 2            1.3           0.2
# 3            1.5           0.2
# 4            1.4           0.2
# 5            1.7           0.4
# 6            1.4           0.3
# 7            1.5           0.2
# 8            1.4           0.2
# 9            1.5           0.1

# %%
# USing Index Also 
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",usecols=[3,4],nrows =10)
# Out:
#    PetalLengthCm  PetalWidthCm
# 0            1.4           0.2
# 1            1.4           0.2
# 2            1.3           0.2
# 3            1.5           0.2
# 4            1.4           0.2
# 5            1.7           0.4
# 6            1.4           0.3
# 7            1.5           0.2
# 8            1.4           0.2
# 9            1.5           0.1

# %%
# Skipping The Rows 
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",skiprows=[1,2,3])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    4.0            4.6           3.1            1.5           0.2
# 1    5.0            5.0           3.6            1.4           0.2
# 2    6.0            5.4           3.9            1.7           0.4
# 3    7.0            4.6           3.4            1.4           0.3
# 4    8.0            5.0           3.4            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 158  NaN            6.7           3.1            5.6           2.4
# 159  NaN            6.9           3.1            5.1           2.3
# 160  NaN            5.8           2.7            5.1           1.9
# 161  NaN            6.8           3.2            NaN           2.3
# 162  NaN            6.7           3.3            5.7           2.5
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Iris.csv",chunksize=10)

# %%
for data in df:
    print(data.shape)
# Out:
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (6, 6)

# %% [markdown]
# # Excel Files

# %% [markdown]
# *sep,
#
# *header
#
# *use cols
#
# *nrows
#
# *names
#
# *chunksize
#
# *skiprows

# %%
# !pip install xlrd
# Out:
# ...
#    ---------------------------------------- 96.5/96.5 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# Sheet-name

# %%
pd.read_excel(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Sample - Superstore.xls")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df1 = pd.read_excel(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Sample - Superstore.xls",sheet_name=0)
df1
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df2 = pd.read_excel(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Sample - Superstore.xls",sheet_name=1)
df2
# Out:
#     Returned        Order ID
# 0        Yes  CA-2017-153822
# 1        Yes  CA-2017-129707
# 2        Yes  CA-2014-152345
# 3        Yes  CA-2015-156440
# 4        Yes  US-2017-155999
# ..       ...             ...
# 291      Yes  CA-2015-101910
# 292      Yes  CA-2017-156958
# 293      Yes  CA-2016-105585
# 294      Yes  CA-2016-148796
# 295      Yes  CA-2015-149636
#
# [296 rows x 2 columns]

# %%
df3 = pd.read_excel(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Sample - Superstore.xls",sheet_name=2)
df3
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
pd.read_csv(r"C:\Users\91771\Desktop\Innomatic\EDA\Pandas\Datasets\Diwali Sales Data.csv",encoding = 'latin1')
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# ## Json File

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 3.8/3.8 MB 7.4 MB/s eta 0:00:00
# ...

# %%
pd.read_html(r"https://en.wikipedia.org/wiki/Indian_Premier_League")
# Out:
# [                             0  \
#  0                          NaN
#  1                    Countries
#  2                Administrator
#  3                 Headquarters
#  4                       Format
#  5                First edition
#  6               Latest edition
#  7            Tournament format
#  8              Number of teams
#  9             Current champion
#  10             Most successful
#  11                   Most runs
#  12                Most wickets
#  13                          TV
#  14                     Website
#  15  2024 Indian Premier League
#
#                                                      1
#  0                                                 NaN
#  1                                               India
#  2        Board of Control for Cricket in India (BCCI)
#  3     Cricket Centre, Churchgate, Mumbai, Maharashtra
#  4                                            Twenty20
#  5                                                2008
# ...

# %%
pd.read_clipboard()
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South
