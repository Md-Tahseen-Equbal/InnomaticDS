# %% [markdown]
# # EDA on Car Price Analysis

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the Data

# %%
df = pd.read_csv(r"C:\Users\91830\Downloads\car_dataset.csv")

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.shape
# Out:
# (4340, 8)

# %%
df['Brand'] = df['name'].str.split(' ').str.get(0)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum() # Missing values
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# Brand            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 763

# %%
df.drop_duplicates(inplace = True) #Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['selling_price'].astype('str').str.isnumeric().sum()
# Out:
# 3577

# %%
df['km_driven'].astype('str').str.isnumeric().sum() #to check proper data without structural errors
# Out:
# 3577

# %%
df.shape
# Out:
# (3577, 9)

# %%
df['Brand'].unique() # to check noisy data
# Out:
# array(['Maruti', 'Hyundai', 'Datsun', 'Honda', 'Tata', 'Chevrolet',
#        'Toyota', 'Jaguar', 'Mercedes-Benz', 'Audi', 'Skoda', 'Jeep',
#        'BMW', 'Mahindra', 'Ford', 'Nissan', 'Renault', 'Fiat',
#        'Volkswagen', 'Volvo', 'Mitsubishi', 'Land', 'Daewoo', 'MG',
#        'Force', 'Isuzu', 'OpelCorsa', 'Ambassador', 'Kia'], dtype=object)

# %%
df.plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ### Data Visualization
# #### Univariate Analysis

# %%
sns.countplot(data = df, x = 'Brand',palette='coolwarm')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\91830\AppData\Local\Temp\ipykernel_2392\1092338874.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x = 'Brand',palette='coolwarm')

# %%
df['Brand'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %%
df['year'].value_counts().nlargest(5).plot(kind = 'bar')
# Out:
# <Axes: xlabel='year'>

# %%
df['year'].value_counts().nsmallest(5).plot(kind = 'bar')
# Out:
# <Axes: xlabel='year'>

# %%
df['fuel'].value_counts().plot(kind = 'pie', autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['fuel'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %%
df['seller_type'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='seller_type'>

# %%
df['transmission'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='transmission'>

# %%
df['owner'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='owner'>

# %% [markdown]
# ### Numerical Data

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %%
df['selling_price'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['km_driven'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  3577.000000   3.577000e+03    3577.000000
# mean   2012.962538   4.739125e+05   69250.545709
# std       4.251759   5.093018e+05   47579.940016
# min    1992.000000   2.000000e+04       1.000000
# 25%    2010.000000   2.000000e+05   36000.000000
# 50%    2013.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df[df['selling_price'] == df['selling_price'].min()]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner Brand
# 2662  Individual       Manual  Second Owner  Ford

# %%
df[df['selling_price'] == df['selling_price'].max()]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner Brand
# 3872      13000  Petrol      Dealer    Automatic  First Owner  Audi

# %%
df[df['km_driven'] == df['km_driven'].min()]
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 1312  Mahindra Quanto C6  2014         250000          1  Diesel  Individual
#
#      transmission         owner     Brand
# 1312       Manual  Second Owner  Mahindra

# %%
df[df['km_driven'] == df['km_driven'].max()]
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 1243  Maruti Swift VXI BSIII  2009         250000     806599  Petrol
#
#      seller_type transmission        owner   Brand
# 1243      Dealer       Manual  First Owner  Maruti

# %% [markdown]
# ### Univariate Analysis Report
# - There are more number of maruthi cars and hyundai at top compared to kia isuzu...etc
# - There are more first owners and second owners at second compared to test drive and third owner cars.
# - There are more cars ranging between 0 to 100000 kms driven.
# - Audi RS7 2015-2019 Sportback Performance is the costliest car in the data set at 89 lakhs.
# - Ford Ikon 1.6 ZXI NXt is the low price car at 20000 There are 58% diesel cars and 48% petrol cars which holds the majority.
# - There are more 2013 to 2017 manufactured cars.

# %% [markdown]
# ## Bi-variate Analysis

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %% [markdown]
# #### Numerical Vs Numerical

# %%
sns.scatterplot(data = df, x = 'km_driven', y = "selling_price")
# Out:
# <Axes: xlabel='km_driven', ylabel='selling_price'>

# %%
sns.scatterplot(data = df, x = 'km_driven', y = "selling_price",hue = 'Brand')
# Out:
# <Axes: xlabel='km_driven', ylabel='selling_price'>

# %%
ax = sns.lineplot(data = df, x = "year", y = "selling_price",hue = 'Brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
# As the year increases avg selling price increases.

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %%
import scipy.stats as st

# %%
df['fuel_transform']= df['fuel'].map({'Petrol':1,'Diesel':2,"CNG":3,"LPG":4,"Electric":5})

# %%
st.pointbiserialr(df['selling_price'],df['fuel_transform'])
# Out:
# SignificanceResult(statistic=0.2140067352678667, pvalue=2.504429085465941e-38)

# %%
sns.scatterplot(data = df, x = 'fuel',y = 'selling_price')
# Out:
# <Axes: xlabel='fuel', ylabel='selling_price'>

# %%
sns.scatterplot(data = df, x = 'km_driven',y = 'selling_price', hue = 'fuel')
# Out:
# <Axes: xlabel='km_driven', ylabel='selling_price'>

# %%
sns.scatterplot(data = df,x = 'selling_price', y = 'seller_type')
# Out:
# <Axes: xlabel='selling_price', ylabel='seller_type'>

# %%
sns.scatterplot(data = df,x = 'selling_price', y = 'transmission')
# Out:
# <Axes: xlabel='selling_price', ylabel='transmission'>

# %%
sns.scatterplot(data = df,x = 'selling_price', y = 'owner')
# Out:
# <Axes: xlabel='selling_price', ylabel='owner'>

# %%
sns.barplot(data = df, x = 'transmission', y = 'selling_price', hue = 'fuel')
# Out:
# <Axes: xlabel='transmission', ylabel='selling_price'>

# %%
sns.catplot(data = df, x = 'transmission', y = 'selling_price', hue = 'fuel', kind = 'bar', col = 'owner')

# %% [markdown]
# - Diesel cars have more selling price especilly the first owner of the cars have high price.
# - Then the petrol cars are on 2nd of the list of haveing high selling price.
# - The Automatic system cars are selling for high price than the manual system cars.
# - The no of owners change of car increases the price will be decreasing.

# %%
sns.catplot(data = df, x = 'transmission', y = 'selling_price', hue = 'fuel', kind = 'bar', row = "year",col = 'owner')

# %%
df.corr(numeric_only=True)
# Out:
#                     year  selling_price  km_driven  fuel_transform
# year            1.000000       0.424260  -0.417490        0.082074
# selling_price   0.424260       1.000000  -0.187359        0.214007
# km_driven      -0.417490      -0.187359   1.000000        0.280836
# fuel_transform  0.082074       0.214007   0.280836        1.000000

# %%
sns.heatmap(data = df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    Brand  fuel_transform
# 0  Individual       Manual   First Owner   Maruti               1
# 1  Individual       Manual   First Owner   Maruti               1
# 2  Individual       Manual   First Owner  Hyundai               2
# 3  Individual       Manual   First Owner   Datsun               1
# 4  Individual       Manual  Second Owner    Honda               2

# %%
# 1. What is the average selling price in 2017?
df[df['year'] == 2017]['selling_price'].mean()
# Out:
# 741184.9277456647

# %%
# 2. What is the averge selliing price of Diesel  car?
df[df['fuel'] == 'Diesel']['selling_price'].mean()
# Out:
# 614001.075

# %%
# 3. How many petrol cars are there?
df[df['fuel'] == 'Petrol'].shape[0]
# Out:
# 1717

# %%
# 4. How many first owner cars of Hyundai are there and what is the maximum selling price?
(df['owner'] == 'First Owner')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338     True
# 4339     True
# Name: owner, Length: 3577, dtype: bool

# %%
hyundai_first_owner = df[(df['name'].str.contains('Hyundai')) & (df['owner'] == 'First Owner')]
num_hyundai_first_owner = hyundai_first_owner.shape[0]
max_price_hyundai_first_owner = hyundai_first_owner['selling_price'].max()

# %%
max_price_hyundai_first_owner
# Out:
# 1650000

# %%
df[df['transmission'] == 'Automatic']['selling_price'].mean()
# Out:
# 1274955.1057692308

# %%
df[(df['fuel'] == 'Diesel') & (df['year'] == 2020)].shape[0]
# Out:
# 13

# %%
df['brand'].value_counts().head(5)
# Out:
# brand
# Maruti      1072
# Hyundai      637
# Mahindra     328
# Tata         308
# Ford         220
# Name: count, dtype: int64

# %%
df[df['brand'] == 'Maruti']['km_driven'].mean()
# Out:
# 65001.34794776119

# %%
df[df['fuel'] == 'Electric']['year'].unique()
# Out:
# array([2006], dtype=int64)

# %%
df[(df['fuel'] == 'Petrol') & (df['year'] == 2017)]['km_driven'].mean()
# Out:
# 32557.92485549133
